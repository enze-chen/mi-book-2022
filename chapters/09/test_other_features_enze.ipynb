# %% [markdown]
# # Test other features
#
# *Authors: Enze Chen (University of California, Berkeley)*
#
# ### Import Python packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

with open('../assets/files/mp_api_key.txt', 'r') as f:
    api_key = f.readlines()[1].strip()
    
from pymatgen.ext.matproj import MPRester
# Out:
# /home/jovyan/.local/lib/python3.9/site-packages/pymatgen/core/__init__.py:51: UserWarning: Error loading .pmgrc.yaml: while scanning a simple key
#   in "/home/jovyan/.pmgrc.yaml", line 5, column 1
# could not find expected ':'
#   in "/home/jovyan/.pmgrc.yaml", line 6, column 17. You may need to reconfigure your yaml file.
#   warnings.warn(f"Error loading .pmgrc.yaml: {ex}. You may need to reconfigure your yaml file.")

# %% [markdown]
# ### Make a query
#
# I've kept this very simple for demonstration.

# %%
criteria = {'diel': {'$exists': True}, 'nelements': {'$lt': 3}}
props = ['material_id', 'pretty_formula', 'structure']

with MPRester(api_key) as mpr:
    res = mpr.query(criteria=criteria, properties=props)
# Out:
# 100%|██████████| 1079/1079 [00:02<00:00, 374.84it/s]

# %% [markdown]
# ### Convert to a DataFrame
#
# But _because_ my query was so simple, I am able to take advantage of built-in converters from `list(dict)` to `DataFrame`. 😎
# See [here](https://stackoverflow.com/questions/20638006/convert-list-of-dictionaries-to-a-pandas-dataframe) for more info (try using Google for other answers).

# %%
df = pd.DataFrame(res)   # ta-da! Easy peasy 
df
# Out:
#      material_id pretty_formula  \
# 0        mp-1000           BaTe
# 1     mp-1008492           BrCl
# 2     mp-1008559             BP
# 3     mp-1009129            MgO
# 4     mp-1009894            ZrC
# ...          ...            ...
# 1074     mp-8938          Si2Mo
# 1075     mp-9063           RbSe
# 1076      mp-971            K2O
# 1077   mvc-11115           TiO2
# 1078   mvc-15643            WO3
#
#                                               structure
# 0      [[0. 0. 0.] Ba, [3.544879 3.544879 3.544879] Te]
# 1     [[0. 0. 0.] Br, [0.        0.        3.9053505...
# 2     [[ 1.600141   -0.92384351  2.65049818] B, [1.6...
# 3     [[0. 0. 0.] Mg, [1.46901    0.84813536 1.33984...
# 4       [[0. 0. 0.] Zr, [1.276538 1.276538 1.276538] C]
# ...                                                 ...
# 1074  [[2.308237   2.68706104 5.51457779] Si, [ 1.13...
# 1075  [[1.47222948 2.54997625 3.1826505 ] Rb, [6.477...
# 1076  [[1.6219385 1.6219385 1.6219385] K, [4.8658155...
# 1077  [[3.25103177 0.         1.18713198] Ti, [ 5.77...
# 1078  [[1.34272004 5.41071875 7.56273194] W, [4.0154...
#
# [1079 rows x 3 columns]

# %% [markdown]
# ### Other featurizers
#
# In addition to `ElementProperty`, matminer has [many more featurizers](https://hackingmaterials.lbl.gov/matminer/matminer.featurizers.html).
# Below we import a few and demonstrate how they work, starting with **composition** featurizers (you've seen `ElementProperty` already).

# %%
from matminer.featurizers.conversions import StrToComposition

from matminer.featurizers.composition.composite import ElementProperty
from matminer.featurizers.composition.element import Stoichiometry, BandCenter
from matminer.featurizers.composition.orbital import AtomicOrbitals, ValenceOrbital
from matminer.featurizers.composition.packing import AtomicPackingEfficiency
from matminer.featurizers.composition.thermo import CohesiveEnergy   # I include this, but unfortunately it doesn't seem to work. API key error.

# %%
str_comp = StrToComposition()
df = str_comp.featurize_dataframe(df, 'pretty_formula')
# Out:
# StrToComposition:   0%|          | 0/1079 [00:00<?, ?it/s]

# %% [markdown]
# #### Demos
#
# Now we'll demonstrate using a few featurizers that we've imported.
# We don't have to do all of them because they all follow the same template format.

# %%
featurizer = Stoichiometry()
df2 = featurizer.featurize_dataframe(df, 'composition')
df2
# Out:
# Stoichiometry:   0%|          | 0/1079 [00:00<?, ?it/s]
#      material_id pretty_formula  \
# 0        mp-1000           BaTe
# 1     mp-1008492           BrCl
# 2     mp-1008559             BP
# 3     mp-1009129            MgO
# 4     mp-1009894            ZrC
# ...          ...            ...
# 1074     mp-8938          Si2Mo
# 1075     mp-9063           RbSe
# 1076      mp-971            K2O
# 1077   mvc-11115           TiO2
# 1078   mvc-15643            WO3
#
#                                               structure composition  0-norm  \
# 0      [[0. 0. 0.] Ba, [3.544879 3.544879 3.544879] Te]    (Ba, Te)       2
# 1     [[0. 0. 0.] Br, [0.        0.        3.9053505...    (Br, Cl)       2
# 2     [[ 1.600141   -0.92384351  2.65049818] B, [1.6...      (B, P)       2
# 3     [[0. 0. 0.] Mg, [1.46901    0.84813536 1.33984...     (Mg, O)       2
# 4       [[0. 0. 0.] Zr, [1.276538 1.276538 1.276538] C]     (Zr, C)       2
# ...                                                 ...         ...     ...
# 1074  [[2.308237   2.68706104 5.51457779] Si, [ 1.13...    (Si, Mo)       2
# 1075  [[1.47222948 2.54997625 3.1826505 ] Rb, [6.477...    (Rb, Se)       2
# 1076  [[1.6219385 1.6219385 1.6219385] K, [4.8658155...      (K, O)       2
# 1077  [[3.25103177 0.         1.18713198] Ti, [ 5.77...     (Ti, O)       2
# 1078  [[1.34272004 5.41071875 7.56273194] W, [4.0154...      (W, O)       2
#
#         2-norm    3-norm    5-norm    7-norm   10-norm
# 0     0.707107  0.629961  0.574349  0.552045  0.535887
# 1     0.707107  0.629961  0.574349  0.552045  0.535887
# 2     0.707107  0.629961  0.574349  0.552045  0.535887
# 3     0.707107  0.629961  0.574349  0.552045  0.535887
# 4     0.707107  0.629961  0.574349  0.552045  0.535887
# ...        ...       ...       ...       ...       ...
# 1074  0.745356  0.693361  0.670782  0.667408  0.666732
# 1075  0.707107  0.629961  0.574349  0.552045  0.535887
# 1076  0.745356  0.693361  0.670782  0.667408  0.666732
# 1077  0.745356  0.693361  0.670782  0.667408  0.666732
# 1078  0.790569  0.759147  0.750616  0.750049  0.750001
#
# [1079 rows x 10 columns]

# %%
featurizer = ValenceOrbital()
df2 = featurizer.featurize_dataframe(df, 'composition')
df2
# Out:
# ValenceOrbital:   0%|          | 0/1079 [00:00<?, ?it/s]
#      material_id pretty_formula  \
# 0        mp-1000           BaTe
# 1     mp-1008492           BrCl
# 2     mp-1008559             BP
# 3     mp-1009129            MgO
# 4     mp-1009894            ZrC
# ...          ...            ...
# 1074     mp-8938          Si2Mo
# 1075     mp-9063           RbSe
# 1076      mp-971            K2O
# 1077   mvc-11115           TiO2
# 1078   mvc-15643            WO3
#
#                                               structure composition  \
# 0      [[0. 0. 0.] Ba, [3.544879 3.544879 3.544879] Te]    (Ba, Te)
# 1     [[0. 0. 0.] Br, [0.        0.        3.9053505...    (Br, Cl)
# 2     [[ 1.600141   -0.92384351  2.65049818] B, [1.6...      (B, P)
# 3     [[0. 0. 0.] Mg, [1.46901    0.84813536 1.33984...     (Mg, O)
# 4       [[0. 0. 0.] Zr, [1.276538 1.276538 1.276538] C]     (Zr, C)
# ...                                                 ...         ...
# 1074  [[2.308237   2.68706104 5.51457779] Si, [ 1.13...    (Si, Mo)
# 1075  [[1.47222948 2.54997625 3.1826505 ] Rb, [6.477...    (Rb, Se)
# 1076  [[1.6219385 1.6219385 1.6219385] K, [4.8658155...      (K, O)
# 1077  [[3.25103177 0.         1.18713198] Ti, [ 5.77...     (Ti, O)
# 1078  [[1.34272004 5.41071875 7.56273194] W, [4.0154...      (W, O)
#
#       avg s valence electrons  avg p valence electrons  \
# 0                    2.000000                 2.000000
# 1                    2.000000                 5.000000
# 2                    2.000000                 2.000000
# 3                    2.000000                 2.000000
# 4                    2.000000                 1.000000
# ...                       ...                      ...
# 1074                 1.666667                 1.333333
# 1075                 1.500000                 2.000000
# 1076                 1.333333                 1.333333
# 1077                 2.000000                 2.666667
# 1078                 2.000000                 3.000000
#
#       avg d valence electrons  avg f valence electrons  \
# 0                    5.000000                      0.0
# 1                    5.000000                      0.0
# 2                    0.000000                      0.0
# 3                    0.000000                      0.0
# 4                    1.000000                      0.0
# ...                       ...                      ...
# 1074                 1.666667                      0.0
# 1075                 5.000000                      0.0
# 1076                 0.000000                      0.0
# 1077                 0.666667                      0.0
# 1078                 1.000000                      3.5
#
#       frac s valence electrons  frac p valence electrons  \
# 0                     0.222222                  0.222222
# 1                     0.166667                  0.416667
# 2                     0.500000                  0.500000
# 3                     0.500000                  0.500000
# 4                     0.500000                  0.250000
# ...                        ...                       ...
# 1074                  0.357143                  0.285714
# 1075                  0.176471                  0.235294
# 1076                  0.500000                  0.500000
# 1077                  0.375000                  0.500000
# 1078                  0.210526                  0.315789
#
#       frac d valence electrons  frac f valence electrons
# 0                     0.555556                  0.000000
# 1                     0.416667                  0.000000
# 2                     0.000000                  0.000000
# 3                     0.000000                  0.000000
# 4                     0.250000                  0.000000
# ...                        ...                       ...
# 1074                  0.357143                  0.000000
# 1075                  0.588235                  0.000000
# 1076                  0.000000                  0.000000
# 1077                  0.125000                  0.000000
# 1078                  0.105263                  0.368421
#
# [1079 rows x 12 columns]

# %% [markdown]
# ### Structural featurizers
#
# To use this featurizer, we have to query for the [`Structure`](https://pymatgen.org/pymatgen.core.structure.html) object directly from Pymatgen and featurize it.
# It doesn't always work, so we have some extra cleanup.
#
# First, some imports.
# There are [many more](https://hackingmaterials.lbl.gov/matminer/featurizer_summary.html#structure) available.

# %%
from matminer.featurizers.structure.order import DensityFeatures, ChemicalOrdering, StructuralComplexity

# %%
featurizer = DensityFeatures()
df3 = featurizer.featurize_dataframe(df, 'structure', ignore_errors=True)
df3 = df3.dropna(how='any', axis=0)
df3
# Out:
# DensityFeatures:   0%|          | 0/1079 [00:00<?, ?it/s]
#      material_id pretty_formula  \
# 0        mp-1000           BaTe
# 1     mp-1008492           BrCl
# 2     mp-1008559             BP
# 3     mp-1009129            MgO
# 4     mp-1009894            ZrC
# ...          ...            ...
# 1074     mp-8938          Si2Mo
# 1075     mp-9063           RbSe
# 1076      mp-971            K2O
# 1077   mvc-11115           TiO2
# 1078   mvc-15643            WO3
#
#                                               structure composition   density  \
# 0      [[0. 0. 0.] Ba, [3.544879 3.544879 3.544879] Te]    (Ba, Te)  4.937886
# 1     [[0. 0. 0.] Br, [0.        0.        3.9053505...    (Br, Cl)  2.527162
# 2     [[ 1.600141   -0.92384351  2.65049818] B, [1.6...      (B, P)  2.953047
# 3     [[0. 0. 0.] Mg, [1.46901    0.84813536 1.33984...     (Mg, O)  3.341014
# 4       [[0. 0. 0.] Zr, [1.276538 1.276538 1.276538] C]     (Zr, C)  5.150550
# ...                                                 ...         ...       ...
# 1074  [[2.308237   2.68706104 5.51457779] Si, [ 1.13...    (Si, Mo)  6.204201
# 1075  [[1.47222948 2.54997625 3.1826505 ] Rb, [6.477...    (Rb, Se)  3.347843
# 1076  [[1.6219385 1.6219385 1.6219385] K, [4.8658155...      (K, O)  2.291176
# 1077  [[3.25103177 0.         1.18713198] Ti, [ 5.77...     (Ti, O)  3.548800
# 1078  [[1.34272004 5.41071875 7.56273194] W, [4.0154...      (W, O)  6.901906
#
#             vpa  packing fraction
# 0     44.545542          0.596286
# 1     37.899200          0.139309
# 2     11.748073          0.287759
# 3     10.015975          0.750898
# 4     16.641452          0.511833
# ...         ...               ...
# 1074  13.570712          0.587555
# 1075  40.778314          0.744663
# 1076  22.756312          1.319916
# 1077  12.456820          0.355992
# 1078  13.944569          0.233430
#
# [1076 rows x 7 columns]

# %%
featurizer = StructuralComplexity()
df3 = featurizer.featurize_dataframe(df, 'structure', ignore_errors=True)
df3 = df3.dropna(how='any', axis=0)
df3
# Out:
# StructuralComplexity:   0%|          | 0/1079 [00:00<?, ?it/s]
#      material_id pretty_formula  \
# 0        mp-1000           BaTe
# 1     mp-1008492           BrCl
# 2     mp-1008559             BP
# 3     mp-1009129            MgO
# 4     mp-1009894            ZrC
# ...          ...            ...
# 1074     mp-8938          Si2Mo
# 1075     mp-9063           RbSe
# 1076      mp-971            K2O
# 1077   mvc-11115           TiO2
# 1078   mvc-15643            WO3
#
#                                               structure composition  \
# 0      [[0. 0. 0.] Ba, [3.544879 3.544879 3.544879] Te]    (Ba, Te)
# 1     [[0. 0. 0.] Br, [0.        0.        3.9053505...    (Br, Cl)
# 2     [[ 1.600141   -0.92384351  2.65049818] B, [1.6...      (B, P)
# 3     [[0. 0. 0.] Mg, [1.46901    0.84813536 1.33984...     (Mg, O)
# 4       [[0. 0. 0.] Zr, [1.276538 1.276538 1.276538] C]     (Zr, C)
# ...                                                 ...         ...
# 1074  [[2.308237   2.68706104 5.51457779] Si, [ 1.13...    (Si, Mo)
# 1075  [[1.47222948 2.54997625 3.1826505 ] Rb, [6.477...    (Rb, Se)
# 1076  [[1.6219385 1.6219385 1.6219385] K, [4.8658155...      (K, O)
# 1077  [[3.25103177 0.         1.18713198] Ti, [ 5.77...     (Ti, O)
# 1078  [[1.34272004 5.41071875 7.56273194] W, [4.0154...      (W, O)
#
#       structural complexity per atom  structural complexity per cell
# 0                           1.000000                        2.000000
# 1                           1.000000                        4.000000
# 2                           1.000000                        4.000000
# 3                           1.000000                        2.000000
# 4                           1.000000                        2.000000
# ...                              ...                             ...
# 1074                        0.918296                        8.264663
# 1075                        1.959148                       23.509775
# 1076                        0.918296                        2.754888
# 1077                        2.396241                       28.754888
# 1078                        2.000000                       32.000000
#
# [1079 rows x 6 columns]

# %% [markdown]
# ### DOS featurizers?
#
# I've never tried this before, but since we're working with electronic materials (dielectrics), it's conceivable that the [band structure](https://en.wikipedia.org/wiki/Electronic_band_structure) and [density of states (DOS)](https://en.wikipedia.org/wiki/Density_of_states) of the material will matter.
# So we'll try to get the DOS of all of our materials and then [featurize that](https://hackingmaterials.lbl.gov/matminer/featurizer_summary.html#dos). 🤞🏼
# Since the DOS is memory intensive, I'll only pull a few.
#
# Here I use the [`df.apply`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.apply.html) method to create a new column by _calling a function_ on an existing column.

# %%
slices = df.iloc[:10, :].copy()
with MPRester(api_key) as mpr:
    slices['dos'] = slices['material_id'].apply(mpr.get_dos_by_material_id)

# %%
from matminer.featurizers.dos import DOSFeaturizer, Hybridization, DosAsymmetry
featurizer = DOSFeaturizer()
slices2 = featurizer.featurize_dataframe(slices, 'dos')
slices2.head()
# Out:
# DOSFeaturizer:   0%|          | 0/10 [00:00<?, ?it/s]
#   material_id pretty_formula  \
# 0     mp-1000           BaTe
# 1  mp-1008492           BrCl
# 2  mp-1008559             BP
# 3  mp-1009129            MgO
# 4  mp-1009894            ZrC
#
#                                            structure composition  \
# 0   [[0. 0. 0.] Ba, [3.544879 3.544879 3.544879] Te]    (Ba, Te)
# 1  [[0. 0. 0.] Br, [0.        0.        3.9053505...    (Br, Cl)
# 2  [[ 1.600141   -0.92384351  2.65049818] B, [1.6...      (B, P)
# 3  [[0. 0. 0.] Mg, [1.46901    0.84813536 1.33984...     (Mg, O)
# 4    [[0. 0. 0.] Zr, [1.276538 1.276538 1.276538] C]     (Zr, C)
#
#                                                  dos  cbm_hybridization  \
# 0  Complete DOS for Full Formula (Ba1 Te1)\nReduc...           0.554323
# 1  Complete DOS for Full Formula (Br2 Cl2)\nReduc...           1.565460
# 2  Complete DOS for Full Formula (B2 P2)\nReduced...           2.067295
# 3  Complete DOS for Full Formula (Mg1 O1)\nReduce...           1.137726
# 4  Complete DOS for Full Formula (Zr1 C1)\nReduce...           0.897080
#
#   cbm_character_1 cbm_specie_1              cbm_location_1  cbm_score_1  \
# 0               d           Ba                 0.0;0.0;0.0     0.845990
# 1               p           Br                 0.0;0.0;0.0     0.276138
# 2               p            B  0.333333;0.666667;0.000274     0.156324
# 3               s           Mg                 0.0;0.0;0.0     0.402906
# 4               d           Zr                 0.0;0.0;0.0     0.684281
#
#    vbm_hybridization vbm_character_1 vbm_specie_1              vbm_location_1  \
# 0           0.456970               p           Te                 0.5;0.5;0.5
# 1           1.380442               p           Br                 0.0;0.0;0.0
# 2           1.401559               p            B  0.333333;0.666667;0.000274
# 3           0.084430               p            O       0.333333;0.666667;0.5
# 4           1.045257               p            C              0.25;0.25;0.25
#
#    vbm_score_1
# 0     0.883160
# 1     0.298244
# 2     0.263503
# 3     0.985728
# 4     0.518033

# %%
featurizer = Hybridization()
slices2 = featurizer.featurize_dataframe(slices, 'dos')
slices2.head()
# Out:
# Hybridization:   0%|          | 0/10 [00:00<?, ?it/s]
#   material_id pretty_formula  \
# 0     mp-1000           BaTe
# 1  mp-1008492           BrCl
# 2  mp-1008559             BP
# 3  mp-1009129            MgO
# 4  mp-1009894            ZrC
#
#                                            structure composition  \
# 0   [[0. 0. 0.] Ba, [3.544879 3.544879 3.544879] Te]    (Ba, Te)
# 1  [[0. 0. 0.] Br, [0.        0.        3.9053505...    (Br, Cl)
# 2  [[ 1.600141   -0.92384351  2.65049818] B, [1.6...      (B, P)
# 3  [[0. 0. 0.] Mg, [1.46901    0.84813536 1.33984...     (Mg, O)
# 4    [[0. 0. 0.] Zr, [1.276538 1.276538 1.276538] C]     (Zr, C)
#
#                                                  dos     cbm_s     cbm_p  \
# 0  Complete DOS for Full Formula (Ba1 Te1)\nReduc...  0.003823  0.079960
# 1  Complete DOS for Full Formula (Br2 Cl2)\nReduc...  0.050917  0.946114
# 2  Complete DOS for Full Formula (B2 P2)\nReduced...  0.457800  0.542200
# 3  Complete DOS for Full Formula (Mg1 O1)\nReduce...  0.778699  0.221301
# 4  Complete DOS for Full Formula (Zr1 C1)\nReduce...  0.019491  0.296228
#
#       cbm_d  cbm_f    cbm_sp  ...     vbm_s     vbm_p     vbm_d  vbm_f  \
# 0  0.916217    0.0  0.001223  ...  0.002449  0.929172  0.068379    0.0
# 1  0.002969    0.0  0.192693  ...  0.000421  0.998468  0.001112    0.0
# 2  0.000000    0.0  0.992877  ...  0.002390  0.997610  0.000000    0.0
# 3  0.000000    0.0  0.689307  ...  0.003194  0.996806  0.000000    0.0
# 4  0.684281    0.0  0.023095  ...  0.012587  0.668020  0.319393    0.0
#
#      vbm_sp    vbm_sd  vbm_sf    vbm_pd  vbm_pf  vbm_df
# 0  0.009102  0.000670     0.0  0.254143     0.0     0.0
# 1  0.001680  0.000002     0.0  0.004440     0.0     0.0
# 2  0.009538  0.000000     0.0  0.000000     0.0     0.0
# 3  0.012735  0.000000     0.0  0.000000     0.0     0.0
# 4  0.033633  0.016081     0.0  0.853443     0.0     0.0
#
# [5 rows x 25 columns]
